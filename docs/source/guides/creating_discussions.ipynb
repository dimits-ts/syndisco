# %% [markdown]
# # Creating a Discussion
#
# The simplest task you can accomplish with this library is to create a small discussion between LLMs.
#
# This guide will teach you the basic setup of the library. You will understand how to setup models, user-agents and how to coordinate them in a discussion. By the end of htis guide, you will be able to run a small discussion with a moderator and save it to the disk for persistence.

# %% [markdown]
# ## Basics

# %% [markdown]
# ### The Model
#
# SynDisco can theoretically support any LLM, as long as it is wrapped in a `BaseModel` wrapper. The `BaseModel` class is a very simple interface with one method. This method gives the underlying LLM input, and returns its output to the library.
#
# There already exists a `TransformersModel` class which handles models from the `transformers` python library. In 90% of your applications, this will be enough. We can load a TransformersModel using the following code:

# %%
from syndisco.model import TransformersModel

llm = TransformersModel(
    model_path="unsloth/Llama-3.2-3B-Instruct-bnb-4bit",
    name="test_model",
    max_out_tokens=100,
)
# Out:
# Loading weights:   0%|          | 0/254 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %% [markdown]
# This will download a small LLM from huggingface. You can substitute the model_path for any similar model in [HuggingFace](https://huggingface.co/) supporting the Transformers library.

# %% [markdown]
# ### Creating personas
#
# All `actors` can be defined by a `persona`, aka a set of attributes that define them. These attributes can be age, ethnicity, and even include special instructions on how they should behave.
#
# Creating a persona programmatically is simple:

# %%
from syndisco.actors import Persona

persona_data = [
    {
        "username": "Emma35",
        "age": 38,
        "sex": "female",
        "education_level": "Bachelor's",
        "sexual_orientation": "Heterosexual",
        "demographic_group": "Latino",
        "current_employment": "Registered Nurse",
        "special_instructions": "",
        "personality_characteristics": [
            "compassionate",
            "patient",
            "diligent",
            "overwhelmed",
        ],
    },
    {
        "username": "Giannis",
        "age": 21,
        "sex": "male",
        "education_level": "College",
        "sexual_orientation": "Pansexual",
        "demographic_group": "White",
        "current_employment": "Game Developer",
        "special_instructions": "",
        "personality_characteristics": [
            "strategic",
            "meticulous",
            "nerdy",
            "hyper-focused",
        ],
    },
]

personas = [Persona(**data) for data in persona_data]

for persona in personas:
    print(persona)
# Out:
# {"username": "Emma35", "age": 38, "sex": "female", "sexual_orientation": "Heterosexual", "demographic_group": "Latino", "current_employment": "Registered Nurse", "education_level": "Bachelor's", "special_instructions": "", "personality_characteristics": ["compassionate", "patient", "diligent", "overwhelmed"]}
# {"username": "Giannis", "age": 21, "sex": "male", "sexual_orientation": "Pansexual", "demographic_group": "White", "current_employment": "Game Developer", "education_level": "College", "special_instructions": "", "personality_characteristics": ["strategic", "meticulous", "nerdy", "hyper-focused"]}

# %% [markdown]
# Since creating a lot of distinct users is essential in running large-scale experiments, users are usually defined in JSON format. That way, you can change anything without touching your code!
#
# [Here](https://github.com/dimits-ts/synthetic_moderation_experiments/blob/master/data/discussions_input/personas/personas.json) is an applied example of how to mass-define user personas through JSON files.

# %% [markdown]
# ### Creating the user-agents
#
# Having a `persona` and a `model` we can finally create an `actor`. The actor will personify the selected persona using the model to talk.
#
# Besides a persona and a model, the actors will also need instructions and a context. By convention, all actors share the same context, and all user-agents share the same instructions. Personalized instructions are defined in the actor's persona.

# %%
from syndisco.actors import Actor, ActorType


CONTEXT = "You are taking part in an online conversation"
INSTRUCTIONS = "Act like a human would"

actors = [
    Actor(
        model=llm,
        persona=p,
        actor_type=ActorType.USER,
        context=CONTEXT,
        instructions=INSTRUCTIONS
    )
    for p in personas
]

# %% [markdown]
# ### Managing turn-taking
#
# In real-life discussions, who gets to speak at each point in time is determined by complex social dynamics, which are difficult to realistically model.
# However, there are ways with which we can simulate these dynamics.
#
# SynDisco uses the `TurnManager` class to model turn taking. Two implementations are available by default: Round Robin, and Random Weighted

# %% [markdown]
# - `Round Robin` is the simplest, most intuitive way to model turn-taking; everyone gets to talk once per round. Once everyone talks once, they get to talk again in the same sequence

# %%
from syndisco.turn_manager import RoundRobin


rrobin_turn_manager = RoundRobin(["John", "Mary", "Howard", "Todd"])

for i in range(10):
    print(next(rrobin_turn_manager))
# Out:
# John
# Mary
# Howard
# Todd
# John
# Mary
# Howard
# Todd
# John
# Mary

# %% [markdown]
# - `RandomWeighted` on the other hand throws a weighted coin on each round. If the coin flip succedes, the previous user gets to respond. If not, another user is selected at random

# %%
from syndisco.turn_manager import RandomWeighted


rweighted_turn_manager = RandomWeighted(
    names=["John", "Mary", "Howard", "Todd"], p_respond=0.5
)

for i in range(10):
    print(next(rweighted_turn_manager))
# Out:
# Mary
# John
# Todd
# John
# Todd
# Mary
# Howard
# John
# Todd
# Mary

# %% [markdown]
# ## Generating a discussion
#
# Let's start with the most basic task; a single discussion between two user-agents.

# %% [markdown]
# Since we only have two users, a RoundRobin approach where each user takes a turn sequentially is sufficient.

# %% [markdown]
# Now we can run a simple discussion

# %%
from syndisco.jobs import Discussion


turn_manager = RoundRobin([actor.get_name() for actor in actors])
conv = Discussion(next_turn_manager=turn_manager, users=actors)
conv.begin()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Emma35 posted:
# "Hey everyone, I just got back from a long shift at the hospital and
# I'm exhausted. Anyone else have a crazy day at work? I feel like I've
# been running non-stop since morning. How was your day?"
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Giannis posted:
# {"role": "Giannis", "content": "Hey Emma, sorry to hear that you're
# exhausted! I had a pretty chill day, just working on some coding for a
# new game project. I've been putting in some long hours lately, but
# it's worth it to see everything come together. How was your shift at
# the hospital? Any interesting cases or stories from the day?"}
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Emma35 posted:
# {"role": "Emma35", "content": "Aww, thanks Giannis! I'm glad to hear
# you had a chill day. As for my shift, it was pretty crazy. We had a
# code blue in the ER and I had to help with the resuscitation. It was
# intense, but thankfully everyone made it through. I also had to do
# some rounds on the pediatric ward and those little ones always put a
# smile on my face. How's your game project coming along?
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Giannis posted:
# "Hey Emma, that sounds like a really tough day at the hospital. I'm
# glad to hear that everyone made it through the code blue okay. The
# pediatric ward is always a highlight of my day, those kids are so full
# of energy and life. As for my game project, I'm making good progress.
# I've been working on implementing a new AI system that's going to give
# the game a lot more depth and realism. I'm also experimenting with
# some new graphics techniques to make the game
#
# User Emma35 posted:
# "Hey Giannis, I'm glad to hear that your game project is going well.
# I'm a bit jealous, to be honest! I've been feeling so burnt out from
# work lately and I don't have the energy to think about coding or game
# development. But I'm sure it's worth it in the end. I've been thinking
# about my shift at the hospital a lot, and I'm still trying to process
# everything that happened. The code blue was intense, but it's a good

# %% [markdown]
# Let's add a moderator to oversee the discussion.

# %%
MODERATOR_INSTRUCTIONS = "You are a moderator. Oversee the discussion"

moderator_persona = Persona(
    **{
        "username": "Moderator",
        "age": 41,
        "sex": "male",
        "education_level": "PhD",
        "sexual_orientation": "Pansexual",
        "demographic_group": "White",
        "current_employment": "Moderator",
        "special_instructions": "",
        "personality_characteristics": [
            "strict",
            "neutral",
            "just",
        ],
    }
)

moderator = Actor(
    model=llm,
    persona=moderator_persona,
    actor_type=ActorType.USER,
    context=CONTEXT,
    instructions=MODERATOR_INSTRUCTIONS
)

# remember to update this!
turn_manager = RoundRobin(
    [actor.get_name() for actor in actors] + [moderator.get_name()]
)
conv = Discussion(
    next_turn_manager=turn_manager,
    users=actors + [moderator],
    moderator=moderator,
)
conv.begin()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Emma35 posted:
# "Hey everyone, I just got back from a long shift at the hospital and
# I'm exhausted. Anyone else have a crazy day at work? I feel like I've
# been running non-stop since morning. How was your day?"
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Moderator posted:
# {"role": "Moderator", "content": "Hi Emma35, sorry to hear that you're
# exhausted. I'm just a computer program, I don't have a physical
# presence, so I didn't have a day at work. However, I'm here to listen
# and chat with you. How about we take a break from the conversation and
# talk about what's been going on in your day? What was the most
# challenging part of your shift?"}
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Giannis posted:
# "Hey Emma, sorry to hear that you're exhausted. I feel you, I've been
# putting in some long hours on my own projects lately. As a game
# developer, I'm always trying to meet deadlines and push the boundaries
# of what's possible. But I think the most challenging part of my day
# was trying to troubleshoot a bug that was driving me crazy. I spent
# hours poring over the code, but I finally figured out the issue and
# was able to squash it. It was a
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Moderator posted:
# {"role": "Moderator", "content": "Thanks for sharing, Giannis. It's
# great to hear that you were able to troubleshoot the bug and get it
# resolved. Sometimes, those long hours can be frustrating, but it's all
# worth it in the end when you see the fruits of your labor. Emma, how
# about you? What was the most challenging part of your shift today? Was
# it dealing with difficult patients or something else?"}
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Moderator posted:
# It seems like the conversation has started. The user Emma35 shared
# that she had a long and exhausting shift at the hospital, and the
# moderator responded by offering to listen and chat with her. Giannis,
# another user, shared his experience of working on a challenging
# project as a game developer and overcoming a difficult bug. The
# moderator then asked Emma to share more about her challenging part of
# the shift.   The conversation is going well, and the moderator is
# doing a good job of keeping the conversation on track
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Moderator posted:
# {"role": "Moderator", "content": "It looks like the conversation is
# going well, and we're having a great discussion about the challenges
# of working in different fields. Emma, would you like to share more
# about your shift at the hospital? What was the most challenging part
# of your day, and how did you manage to stay energized throughout your
# shift?"}
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Emma35 posted:
# "Thank you so much for listening, Moderator. To be honest, it was a
# tough day at the hospital. We had a code blue come in, and it was a
# real challenge to stay calm and focused. I had to think on my feet and
# make some quick decisions to get the patient stabilized. It was a lot
# of pressure, but I've been doing this job for a while, so I try to
# stay calm and trust my training. The most challenging part was
# probably the emotional toll it
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Moderator posted:
# It seems like the conversation has started. The user Emma35 shared
# that she had a long and exhausting shift at the hospital, and the
# moderator responded by offering to listen and chat with her. Giannis,
# another user, shared his experience of working on a challenging
# project as a game developer and overcoming a difficult bug. The
# moderator then asked Emma to share more about her challenging part of
# the shift.
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Giannis posted:
# "Thanks for sharing, Emma. I can imagine how tough it must have been
# to deal with a code blue. As a game developer, I've had my fair share
# of dealing with difficult bugs, but I think the pressure of a real-
# life situation like that must be a whole different level. I've had to
# work under tight deadlines and with limited resources, but at least I
# can take a break when I need to. Did you have any support from your
# team during the code blue, or was
#
# User Moderator posted:
# {"role": "Moderator", "content": "Great point, Giannis. Having a
# supportive team can make a big difference in high-pressure situations
# like a code blue. Emma, can you tell us more about the support you
# received from your team during that time? Were there any specific team
# members who stood out to you as being particularly helpful or
# reassuring?"}

# %% [markdown]
# ### Saving a discussion to the disk
#
# It's best practice to save the results of each discussion after it has concluded. This way, no matter what happens to the program executing the discussions, progress will be checkpointed.
#
# The `Discussion` class provides a method for saving its logs and related metadata to a JSON file:

# %%
import tempfile
import json

tp = tempfile.NamedTemporaryFile(delete=True)

conv.to_json_file(tp.name)

# if you are running this on Windows, uncomment this line
# tp.close()
with open(tp.name, mode="rb") as f:
    print(json.dumps(json.load(f), indent=2))
# Out:
# {
#   "id": "c112a0ae-5a6d-4fdf-93bf-43540febcfe5",
#   "timestamp": "26-03-17-15-44",
#   "users": [
#     "Emma35",
#     "Giannis",
#     "Moderator"
#   ],
#   "moderator": "Moderator",
#   "user_prompts": [
#     "{\"context\": \"You are taking part in an online conversation\", \"instructions\": \"Act like a human would\", \"type\": \"1\", \"persona\": {\"username\": \"Emma35\", \"age\": 38, \"sex\": \"female\", \"sexual_orientation\": \"Heterosexual\", \"demographic_group\": \"Latino\", \"current_employment\": \"Registered Nurse\", \"education_level\": \"Bachelor's\", \"special_instructions\": \"\", \"personality_characteristics\": [\"compassionate\", \"patient\", \"diligent\", \"overwhelmed\"]}}",
#     "{\"context\": \"You are taking part in an online conversation\", \"instructions\": \"Act like a human would\", \"type\": \"1\", \"persona\": {\"username\": \"Giannis\", \"age\": 21, \"sex\": \"male\", \"sexual_orientation\": \"Pansexual\", \"demographic_group\": \"White\", \"current_employment\": \"Game Developer\", \"education_level\": \"College\", \"special_instructions\": \"\", \"personality_characteristics\": [\"strategic\", \"meticulous\", \"nerdy\", \"hyper-focused\"]}}",
#     "{\"context\": \"You are taking part in an online conversation\", \"instructions\": \"You are a moderator. Oversee the discussion\", \"type\": \"1\", \"persona\": {\"username\": \"Moderator\", \"age\": 41, \"sex\": \"male\", \"sexual_orientation\": \"Pansexual\", \"demographic_group\": \"White\", \"current_employment\": \"Moderator\", \"education_level\": \"PhD\", \"special_instructions\": \"\", \"personality_characteristics\": [\"strict\", \"neutral\", \"just\"]}}"
#   ],
#   "moderator_prompt": "{\"context\": \"You are taking part in an online conversation\", \"instructions\": \"You are a moderator. Oversee the discussion\", \"type\": \"1\", \"persona\": {\"username\": \"Moderator\", \"age\": 41, \"sex\": \"male\", \"sexual_orientation\": \"Pansexual\", \"demographic_group\": \"White\", \"current_employment\": \"Moderator\", \"education_level\": \"PhD\", \"special_instructions\": \"\", \"personality_characteristics\": [\"strict\", \"neutral\", \"just\"]}}",
#   "ctx_length": 5,
#   "logs": [
#     {
#       "name": "Emma35",
#       "text": "\"Hey everyone, I just got back from a long shift at the hospital and I'm exhausted. Anyone else have a crazy day at work? I feel like I've been running non-stop since morning. How was your day?\"",
#       "model": "test_model"
#     },
#     {
#       "name": "Moderator",
#       "text": "{\"role\": \"Moderator\", \"content\": \"Hi Emma35, sorry to hear that you're exhausted. I'm just a computer program, I don't have a physical presence, so I didn't have a day at work. However, I'm here to listen and chat with you. How about we take a break from the conversation and talk about what's been going on in your day? What was the most challenging part of your shift?\"}",
#       "model": "test_model"
#     },
#     {
#       "name": "Giannis",
#       "text": "\"Hey Emma, sorry to hear that you're exhausted. I feel you, I've been putting in some long hours on my own projects lately. As a game developer, I'm always trying to meet deadlines and push the boundaries of what's possible. But I think the most challenging part of my day was trying to troubleshoot a bug that was driving me crazy. I spent hours poring over the code, but I finally figured out the issue and was able to squash it. It was a",
#       "model": "test_model"
#     },
#     {
#       "name": "Moderator",
#       "text": "{\"role\": \"Moderator\", \"content\": \"Thanks for sharing, Giannis. It's great to hear that you were able to troubleshoot the bug and get it resolved. Sometimes, those long hours can be frustrating, but it's all worth it in the end when you see the fruits of your labor. Emma, how about you? What was the most challenging part of your shift today? Was it dealing with difficult patients or something else?\"}",
#       "model": "test_model"
#     },
#     {
#       "name": "Moderator",
#       "text": "It seems like the conversation has started. The user Emma35 shared that she had a long and exhausting shift at the hospital, and the moderator responded by offering to listen and chat with her. Giannis, another user, shared his experience of working on a challenging project as a game developer and overcoming a difficult bug. The moderator then asked Emma to share more about her challenging part of the shift. \n\nThe conversation is going well, and the moderator is doing a good job of keeping the conversation on track",
#       "model": "test_model"
#     },
#     {
#       "name": "Moderator",
#       "text": "{\"role\": \"Moderator\", \"content\": \"It looks like the conversation is going well, and we're having a great discussion about the challenges of working in different fields. Emma, would you like to share more about your shift at the hospital? What was the most challenging part of your day, and how did you manage to stay energized throughout your shift?\"}",
#       "model": "test_model"
#     },
#     {
#       "name": "Emma35",
#       "text": "\"Thank you so much for listening, Moderator. To be honest, it was a tough day at the hospital. We had a code blue come in, and it was a real challenge to stay calm and focused. I had to think on my feet and make some quick decisions to get the patient stabilized. It was a lot of pressure, but I've been doing this job for a while, so I try to stay calm and trust my training. The most challenging part was probably the emotional toll it",
#       "model": "test_model"
#     },
#     {
#       "name": "Moderator",
#       "text": "It seems like the conversation has started. The user Emma35 shared that she had a long and exhausting shift at the hospital, and the moderator responded by offering to listen and chat with her. Giannis, another user, shared his experience of working on a challenging project as a game developer and overcoming a difficult bug. The moderator then asked Emma to share more about her challenging part of the shift.",
#       "model": "test_model"
#     },
#     {
#       "name": "Giannis",
#       "text": "\"Thanks for sharing, Emma. I can imagine how tough it must have been to deal with a code blue. As a game developer, I've had my fair share of dealing with difficult bugs, but I think the pressure of a real-life situation like that must be a whole different level. I've had to work under tight deadlines and with limited resources, but at least I can take a break when I need to. Did you have any support from your team during the code blue, or was",
#       "model": "test_model"
#     },
#     {
#       "name": "Moderator",
#       "text": "{\"role\": \"Moderator\", \"content\": \"Great point, Giannis. Having a supportive team can make a big difference in high-pressure situations like a code blue. Emma, can you tell us more about the support you received from your team during that time? Were there any specific team members who stood out to you as being particularly helpful or reassuring?\"}",
#       "model": "test_model"
#     }
#   ]
# }

# %% [markdown]
# Congratulations, you can now run fully synthetic discussions! You may want to experiment with adding more than 2 users or testing more realistic turn taking procedures (for example, check out the `RandomWeighted` turn manager).
