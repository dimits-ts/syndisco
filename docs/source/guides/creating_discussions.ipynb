# %% [markdown]
# # Creating a Discussion
#
# The simplest task you can accomplish with this library is to create a small discussion between LLMs.
#
# This guide will teach you the basic setup of the library. You will understand how to setup models, user-agents and how to coordinate them in a discussion. By the end of htis guide, you will be able to run a small discussion with a moderator and save it to the disk for persistence.

# %%
# %env CUDA_VISIBLE_DEVICES=0
# %env HF_HOME=/media/SSD_4TB_2/dtsirmpas/hugging_face_cache
# Out:
# env: CUDA_VISIBLE_DEVICES=0
# env: HF_HOME=/media/SSD_4TB_2/dtsirmpas/hugging_face_cache

# %% [markdown]
# ## Basics

# %% [markdown]
# ### The Model
#
# SynDisco can theoretically support any LLM, as long as it is wrapped in a `BaseModel` wrapper. The `BaseModel` class is a very simple interface with one method. This method gives the underlying LLM input, and returns its output to the library.
#
# There already exists a `TransformersModel` class which handles models from the `transformers` python library. In 90% of your applications, this will be enough. We can load a TransformersModel using the following code:

# %%
from syndisco.model import TransformersModel

llm = TransformersModel(
    model_path="unsloth/Llama-3.2-3B-Instruct-bnb-4bit",
    name="test_model",
    max_out_tokens=100,
)

# %% [markdown]
# This will download a small LLM from huggingface. You can substitute the model_path for any similar model in [HuggingFace](https://huggingface.co/) supporting the Transformers library.

# %% [markdown]
# ### Creating personas
#
# All `actors` can be defined by a `persona`, aka a set of attributes that define them. These attributes can be age, ethnicity, and even include special instructions on how they should behave.
#
# Creating a persona programmatically is simple:

# %%
from syndisco.actors import Persona

persona_data = [
    {
        "username": "Emma35",
        "age": 38,
        "sex": "female",
        "education_level": "Bachelor's",
        "sexual_orientation": "Heterosexual",
        "demographic_group": "Latino",
        "current_employment": "Registered Nurse",
        "special_instructions": "",
        "personality_characteristics": [
            "compassionate",
            "patient",
            "diligent",
            "overwhelmed",
        ],
    },
    {
        "username": "Giannis",
        "age": 21,
        "sex": "male",
        "education_level": "College",
        "sexual_orientation": "Pansexual",
        "demographic_group": "White",
        "current_employment": "Game Developer",
        "special_instructions": "",
        "personality_characteristics": [
            "strategic",
            "meticulous",
            "nerdy",
            "hyper-focused",
        ],
    },
]

personas = [Persona(**data) for data in persona_data]

for persona in personas:
    print(persona)
# Out:
# {"username": "Emma35", "age": 38, "sex": "female", "sexual_orientation": "Heterosexual", "demographic_group": "Latino", "current_employment": "Registered Nurse", "education_level": "Bachelor's", "special_instructions": "", "personality_characteristics": ["compassionate", "patient", "diligent", "overwhelmed"]}
# {"username": "Giannis", "age": 21, "sex": "male", "sexual_orientation": "Pansexual", "demographic_group": "White", "current_employment": "Game Developer", "education_level": "College", "special_instructions": "", "personality_characteristics": ["strategic", "meticulous", "nerdy", "hyper-focused"]}

# %% [markdown]
# Since creating a lot of distinct users is essential in running large-scale experiments, users are usually defined in JSON format. That way, you can change anything without touching your code!
#
# [Here](https://github.com/dimits-ts/synthetic_moderation_experiments/blob/master/data/discussions_input/personas/personas.json) is an applied example of how to mass-define user personas through JSON files.

# %% [markdown]
# ### Creating the user-agents
#
# Having a `persona` and a `model` we can finally create an `actor`. The actor will personify the selected persona using the model to talk.
#
# Besides a persona and a model, the actors will also need instructions and a context. By convention, all actors share the same context, and all user-agents share the same instructions. Personalized instructions are defined in the actor's persona.

# %%
from syndisco.actors import Actor, ActorType


CONTEXT = "You are taking part in an online conversation"
INSTRUCTIONS = "Act like a human would"

actors = [
    Actor(
        model=llm,
        persona=p,
        actor_type=ActorType.USER,
        context=CONTEXT,
        instructions=INSTRUCTIONS
    )
    for p in personas
]

# %% [markdown]
# ### Managing turn-taking
#
# In real-life discussions, who gets to speak at each point in time is determined by complex social dynamics, which are difficult to realistically model.
# However, there are ways with which we can simulate these dynamics.
#
# SynDisco uses the `TurnManager` class to model turn taking. Two implementations are available by default: Round Robin, and Random Weighted

# %% [markdown]
# - `Round Robin` is the simplest, most intuitive way to model turn-taking; everyone gets to talk once per round. Once everyone talks once, they get to talk again in the same sequence

# %%
from syndisco.turn_manager import RoundRobin


rrobin_turn_manager = RoundRobin(["John", "Mary", "Howard", "Todd"])

for i in range(10):
    print(next(rrobin_turn_manager))
# Out:
# John
# Mary
# Howard
# Todd
# John
# Mary
# Howard
# Todd
# John
# Mary

# %% [markdown]
# - `RandomWeighted` on the other hand throws a weighted coin on each round. If the coin flip succedes, the previous user gets to respond. If not, another user is selected at random

# %%
from syndisco.turn_manager import RandomWeighted


rweighted_turn_manager = RandomWeighted(
    names=["John", "Mary", "Howard", "Todd"], p_respond=0.5
)

for i in range(10):
    print(next(rweighted_turn_manager))
# Out:
# Mary
# Howard
# Mary
# John
# Todd
# John
# Howard
# Mary
# Howard
# Mary

# %% [markdown]
# ## Generating a discussion
#
# Let's start with the most basic task; a single discussion between two user-agents.

# %% [markdown]
# Since we only have two users, a RoundRobin approach where each user takes a turn sequentially is sufficient.

# %% [markdown]
# Now we can run a simple discussion

# %%
from syndisco.jobs import Discussion


turn_manager = RoundRobin([actor.get_name() for actor in actors])
conv = Discussion(next_turn_manager=turn_manager, users=actors)
conv.begin()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# User Emma35 posted:
# "Hey everyone, I just got back from a long shift at the hospital and
# I'm exhausted. Anyone else have a crazy day at work? I feel like I've
# been running non-stop since morning. How was your day?"
#
# User Giannis posted:
# {"role": "Giannis", "content": "Hey Emma, sorry to hear that you're
# exhausted! I had a pretty chill day at the office, just working on
# some game development stuff. I've been putting in some long hours
# lately, but it's worth it to see our game come together. How about
# you, did anything crazy happen at the hospital?"
#
# User Emma35 posted:
# "Hey Giannis, thanks for checking in! I'm glad to hear you had a chill
# day at the office. As for me, it was a typical chaotic day at the
# hospital. We had a code blue come in and I had to rush to the ER to
# help with the situation. It was intense, but thankfully everyone made
# it through okay. I'm just looking forward to getting some rest now.
# How's the game development going? I'm always curious to see what
# you're working on
#
# User Giannis posted:
# "Hey Emma, I'm glad you're okay after that crazy code blue at the
# hospital. That sounds like a really intense situation to be in. As for
# the game, we're actually working on a new level for our upcoming
# release. We're trying to perfect the physics engine to make the
# gameplay feel more realistic. I've been spending a lot of time
# tweaking the code and testing different scenarios to make sure
# everything feels smooth and responsive. It's been a challenge, but I'm
# excited to see
#
# User Emma35 posted:
# "Aw, thank you so much, Giannis! I'm glad to hear that the game
# development is going well. I'm always excited to see what you're
# working on. I'm a bit jealous, to be honest - I wish I had a game to
# work on instead of dealing with code blues and hospital chaos all day.
# But I'm sure it's worth it in the end. I'm just looking forward to
# getting some rest and maybe catching up on some sleep. Do you have any

# %% [markdown]
# ### Saving a discussion to the disk
#
# It's best practice to save the results of each discussion after it has concluded. This way, no matter what happens to the program executing the discussions, progress will be checkpointed.
#
# The `Discussion` class provides a method for saving its logs and related metadata to a JSON file:

# %%
import tempfile
import json

tp = tempfile.NamedTemporaryFile(delete=True)

conv.to_json_file(tp.name)

# if you are running this on Windows, uncomment this line
# tp.close()
with open(tp.name, mode="rb") as f:
    print(json.dumps(json.load(f), indent=2))
# Out:
# {
#   "timestamp": "26-04-01-16-01",
#   "logs": [
#     {
#       "name": "Emma35",
#       "text": "\"Hey everyone, I just got back from a long shift at the hospital and I'm exhausted. Anyone else have a crazy day at work? I feel like I've been running non-stop since morning. How was your day?\"",
#       "model": "test_model"
#     },
#     {
#       "name": "Giannis",
#       "text": "{\"role\": \"Giannis\", \"content\": \"Hey Emma, sorry to hear that you're exhausted! I had a pretty chill day at the office, just working on some game development stuff. I've been putting in some long hours lately, but it's worth it to see our game come together. How about you, did anything crazy happen at the hospital?\"",
#       "model": "test_model"
#     },
#     {
#       "name": "Emma35",
#       "text": "\"Hey Giannis, thanks for checking in! I'm glad to hear you had a chill day at the office. As for me, it was a typical chaotic day at the hospital. We had a code blue come in and I had to rush to the ER to help with the situation. It was intense, but thankfully everyone made it through okay. I'm just looking forward to getting some rest now. How's the game development going? I'm always curious to see what you're working on",
#       "model": "test_model"
#     },
#     {
#       "name": "Giannis",
#       "text": "\"Hey Emma, I'm glad you're okay after that crazy code blue at the hospital. That sounds like a really intense situation to be in. As for the game, we're actually working on a new level for our upcoming release. We're trying to perfect the physics engine to make the gameplay feel more realistic. I've been spending a lot of time tweaking the code and testing different scenarios to make sure everything feels smooth and responsive. It's been a challenge, but I'm excited to see",
#       "model": "test_model"
#     },
#     {
#       "name": "Emma35",
#       "text": "\"Aw, thank you so much, Giannis! I'm glad to hear that the game development is going well. I'm always excited to see what you're working on. I'm a bit jealous, to be honest - I wish I had a game to work on instead of dealing with code blues and hospital chaos all day. But I'm sure it's worth it in the end. I'm just looking forward to getting some rest and maybe catching up on some sleep. Do you have any",
#       "model": "test_model"
#     }
#   ],
#   "id": "02f84c98-97ea-4e63-82b1-0f18052353d7",
#   "users": [
#     "Emma35",
#     "Giannis"
#   ],
#   "user_prompts": [
#     "{\"context\": \"You are taking part in an online conversation\", \"instructions\": \"Act like a human would\", \"type\": \"1\", \"persona\": {\"username\": \"Emma35\", \"age\": 38, \"sex\": \"female\", \"sexual_orientation\": \"Heterosexual\", \"demographic_group\": \"Latino\", \"current_employment\": \"Registered Nurse\", \"education_level\": \"Bachelor's\", \"special_instructions\": \"\", \"personality_characteristics\": [\"compassionate\", \"patient\", \"diligent\", \"overwhelmed\"]}}",
#     "{\"context\": \"You are taking part in an online conversation\", \"instructions\": \"Act like a human would\", \"type\": \"1\", \"persona\": {\"username\": \"Giannis\", \"age\": 21, \"sex\": \"male\", \"sexual_orientation\": \"Pansexual\", \"demographic_group\": \"White\", \"current_employment\": \"Game Developer\", \"education_level\": \"College\", \"special_instructions\": \"\", \"personality_characteristics\": [\"strategic\", \"meticulous\", \"nerdy\", \"hyper-focused\"]}}"
#   ],
#   "ctx_length": 5
# }

# %% [markdown]
# ## Driving a discussion step by step
#
# `Discussion` implements Python's iterator protocol, so you are not limited
# to running the whole conversation at once with `begin()`. You can drive it
# one turn at a time, which is useful when you want to inspect or react to
# each entry before the next speaker is prompted — for example to apply
# early stopping, live logging, or conditional branching.
#
# Because `Discussion` is its own iterator (`__iter__` returns `self`), it
# is **single-pass**: once `StopIteration` is raised the instance is
# exhausted and should not be reused.

# %% [markdown]
# ### Calling `next()` manually
#
# Calling `iter()` on a `Discussion` performs the one-time setup (registering
# participant names and inserting any seed opinions). Each subsequent `next()`
# prompts one speaker and returns the new log entry as a plain dict.

# %%
from syndisco.jobs import Discussion
from syndisco.turn_manager import RoundRobin


turn_manager = RoundRobin([actor.get_name() for actor in actors])
conv = Discussion(next_turn_manager=turn_manager, users=actors, conv_len=4)

it = iter(conv)  # one-time setup happens here

first_entry = next(it)
print("First speaker: ", first_entry["name"])
print("Their message: ", first_entry["text"], "...")

second_entry = next(it)
print("\nSecond speaker:", second_entry["name"])
print("Their message: ", second_entry["text"], "...")
# Out:
# First speaker:  Emma35
# Their message:  "Hey everyone, I just got back from a long shift at the hospital and I'm exhausted. Anyone else have a crazy day at work? I feel like I've been running non-stop since morning. How was your day?" ...
#
# Second speaker: Giannis
# Their message:  {"role": "Giannis", "content": "Hey Emma, sorry to hear that you're exhausted! I had a pretty chill day at the office, just working on some game development stuff. I've been putting in some long hours lately, but it's worth it to see our game come together. How about you, did anything crazy happen at the hospital?" ...

# %% [markdown]
# ### Using a `for` loop
#
# The same iterator works directly in a `for` loop. Here we stop early if
# a particular word appears in an entry — something that is impossible with
# `begin()`.

# %%
turn_manager = RoundRobin([actor.get_name() for actor in actors])
conv = Discussion(next_turn_manager=turn_manager, users=actors, conv_len=10)

STOP_WORD = "hospital"

for entry in conv:
    print(f"{entry['name']}: {entry['text']}...")
    if STOP_WORD in entry["text"].lower():
        print(f"\nStop word '{STOP_WORD}' detected — halting early.")
        break

print(f"\nTurns completed so far: {conv._steps_taken}")
# Out:
# Emma35: "Hey everyone, I just got back from a long shift at the hospital and I'm exhausted. Anyone else have a crazy day at work? I feel like I've been running non-stop since morning. How was your day?"...
#
# Stop word 'hospital' detected — halting early.
#
# Turns completed so far: 1

# %% [markdown]
# ## Working with `DiscussionLogs`
#
# All log state is held in `Discussion.logs`, an instance of `DiscussionLogs`.
# This object supports the standard sequence interface, so you can index,
# slice, and iterate over it directly — no need to call `to_dict()` just to
# inspect entries.

# %%
# Run a fresh discussion so the logs are fully populated
turn_manager = RoundRobin([actor.get_name() for actor in actors])
conv = Discussion(next_turn_manager=turn_manager, users=actors, conv_len=4)
conv.begin(verbose=False)

logs = conv.logs

print(f"Total entries : {len(logs)}")
print(f"First entry   : {logs[0]}")
print(f"Last entry    : {logs[-1]}")
print()

# Iterate directly — each item is a dict with 'name', 'text', 'model'
for entry in logs:
    print(f"[{entry['name']}] {entry['text'][:60]}...")
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Total entries : 4
# First entry   : {'name': 'Emma35', 'text': '"Hey everyone, I just got back from a long shift at the hospital and I\'m exhausted. Anyone else have a crazy day at work? I feel like I\'ve been running non-stop since morning. How was your day?"', 'model': 'test_model'}
# Last entry    : {'name': 'Giannis', 'text': '"Hey Emma, I\'m glad you\'re okay after that crazy code blue at the hospital. That sounds like a really intense situation to be in. As for the game, we\'re actually working on a new level for our upcoming release. We\'re trying to perfect the physics engine to make the gameplay feel more realistic. I\'ve been spending a lot of time tweaking the code and testing different scenarios to make sure everything feels smooth and responsive. It\'s been a challenge, but I\'m excited to see', 'model': 'test_model'}
#
# [Emma35] "Hey everyone, I just got back from a long shift at the hosp...
# [Giannis] {"role": "Giannis", "content": "Hey Emma, sorry to hear that...
# [Emma35] "Hey Giannis, thanks for checking in! I'm glad to hear you h...
# [Giannis] "Hey Emma, I'm glad you're okay after that crazy code blue a...

# %% [markdown]
# ## Loading a saved discussion as `DiscussionLogs`
#
# A discussion saved to JSON can be reloaded as a `DiscussionLogs` object
# using `DiscussionLogs.from_lists()`. This lets you inspect, serialize, or
# pass saved conversations to an `Annotation` job without re-running the
# discussion.
#
# `from_lists` accepts three parallel lists — names, texts, and (optionally)
# model labels — and is the canonical way to construct a `DiscussionLogs`
# from an external source.

# %%
import json
import tempfile
from syndisco.jobs import DiscussionLogs


# ── Save the discussion we ran above ────────────────────────────────────
tp = tempfile.NamedTemporaryFile(suffix=".json", delete=False)
conv.to_json_file(tp.name)

# ── Reload the raw JSON ──────────────────────────────────────────────────
with open(tp.name) as f:
    saved = json.load(f)

# ── Reconstruct a DiscussionLogs from the saved lists ───────────────────
reloaded_logs = DiscussionLogs.from_lists(
    names=[entry["name"]  for entry in saved["logs"]],
    texts=[entry["text"]  for entry in saved["logs"]],
    models=[entry["model"] for entry in saved["logs"]],
)

print(f"Reloaded {len(reloaded_logs)} entries")
print()
for entry in reloaded_logs:
    print(f"[{entry['name']} / {entry['model']}] {entry['text'][:60]}...")
# Out:
# Reloaded 4 entries
#
# [Emma35 / test_model] "Hey everyone, I just got back from a long shift at the hosp...
# [Giannis / test_model] {"role": "Giannis", "content": "Hey Emma, sorry to hear that...
# [Emma35 / test_model] "Hey Giannis, thanks for checking in! I'm glad to hear you h...
# [Giannis / test_model] "Hey Emma, I'm glad you're okay after that crazy code blue a...

# %% [markdown]
# `from_lists` also makes it easy to construct a `DiscussionLogs` from
# scratch — for example to represent a human-authored conversation, or to
# create a seed discussion for testing without spinning up any models.

# %%
handcrafted = DiscussionLogs.from_lists(
    names=["Alice", "Bob", "Alice"],
    texts=[
        "What do you think about the new policy?",
        "Honestly, I think it goes too far.",
        "I can see that perspective, though I'm not sure I agree.",
    ],
    # 'models' defaults to 'hardcoded' when omitted
)

print(f"Entries: {len(handcrafted)}")
for entry in handcrafted:
    print(f"  {entry['name']} ({entry['model']}): {entry['text']}")
# Out:
# Entries: 3
#   Alice (hardcoded): What do you think about the new policy?
#   Bob (hardcoded): Honestly, I think it goes too far.
#   Alice (hardcoded): I can see that perspective, though I'm not sure I agree.

# %% [markdown]
# Congratulations, you can now run fully synthetic discussions! You may want to experiment with adding more than 2 users or testing more realistic turn taking procedures (for example, check out the `RandomWeighted` turn manager).
